# %%
# =================================================
# GRAPH 5: Predicted Forest Loss Over Years
# =================================================
yearly_data["predicted_forest_loss"] = df.groupby("year")["predicted_forest_loss"].mean()
plt.figure()
plt.plot(yearly_data.index, yearly_data["predicted_forest_loss"])
plt.xlabel("Year")
plt.ylabel("Predicted Forest Loss (sqkm)")
plt.title("Predicted Forest Loss Over Years (Line Graph)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# =================================================
# GRAPH 6: Actual vs Predicted Forest Loss Trend
# =================================================
plt.figure()
plt.plot(yearly_data.index, yearly_data["forest_loss_sqkm"], label="Actual")
plt.plot(yearly_data.index, yearly_data["predicted_forest_loss"], label="Predicted")
plt.xlabel("Year")
plt.ylabel("Forest Loss (sqkm)")
plt.title("Actual vs Predicted Forest Loss Trend (Line Graph)")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# =================================================
# GRAPH 7: Residual Error Over Years
# =================================================
df["residual"] = df["forest_loss_sqkm"] - df["predicted_forest_loss"]
yearly_residual = df.groupby("year")["residual"].mean()

plt.figure()
plt.plot(yearly_residual.index, yearly_residual)
plt.xlabel("Year")
plt.ylabel("Residual Error")
plt.title("Residual Error Over Years (Line Graph)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# =================================================
# GRAPH 8: Agricultural Expansion vs Forest Loss Trend
# =================================================
plt.figure()
plt.plot(yearly_data.index, yearly_data["agricultural_expansion_sqkm"], label="Agriculture")
plt.plot(yearly_data.index, yearly_data["forest_loss_sqkm"], label="Forest Loss")
plt.xlabel("Year")
plt.ylabel("Value")
plt.title("Agricultural Expansion vs Forest Loss Trend (Line Graph)")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
