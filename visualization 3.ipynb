# %%
# =================================================
# GRAPH 9: Cattle Density vs Forest Loss Trend
# =================================================
plt.figure()
plt.plot(yearly_data.index, yearly_data["cattle_density"], label="Cattle Density")
plt.plot(yearly_data.index, yearly_data["forest_loss_sqkm"], label="Forest Loss")
plt.xlabel("Year")
plt.ylabel("Value")
plt.title("Cattle Density vs Forest Loss Trend (Line Graph)")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# =================================================
# GRAPH 10:Model Performance (R² Score) Over Time
# =================================================
r2_score = model.score(X, Y)
r2_line = [r2_score] * len(yearly_data.index)

plt.figure()
plt.plot(yearly_data.index, r2_line)
plt.xlabel("Year")
plt.ylabel("R² Score")
plt.title("Model Performance (R² Score) Over Time (Line Graph)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# =================================================
# GRAPH 11: Driver Importance
# =================================================
drivers = ["Agricultural Expansion", "Cattle Density"]
importance = model.coef_

plt.figure()
plt.bar(drivers, importance)

plt.xlabel("Drivers")
plt.ylabel("Coefficient Value")
plt.title("Driver Importance (Bar Graph)")
plt.tight_layout()
plt.show()
