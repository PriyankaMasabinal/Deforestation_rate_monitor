# %%
# =================================================
# GRAPH 1: Forest Loss Over Years
# =================================================

plt.figure()
plt.plot(yearly_data.index, yearly_data["forest_loss_sqkm"])
plt.xlabel("Year")
plt.ylabel("Forest Loss (sqkm)")
plt.title("Forest Loss Over Years (Line Graph)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# =================================================
# GRAPH 2: Agricultural Expansion Over Years
# =================================================
plt.figure()
plt.plot(yearly_data.index, yearly_data["agricultural_expansion_sqkm"])
plt.xlabel("Year")
plt.ylabel("Agricultural Expansion (sqkm)")
plt.title("Agricultural Expansion Over Years (Line Graph)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# =================================================
# GRAPH 3: Cattle Density Over Years
# =================================================
plt.figure()
plt.plot(yearly_data.index, yearly_data["cattle_density"])
plt.xlabel("Year")
plt.ylabel("Cattle Density")
plt.title("Cattle Density Over Years (Line Graph)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# =================================================
# GRAPH 4:Combined Normalized Trend of Forest Loss, Agriculture & Cattle
# =================================================
plt.figure()
plt.plot(yearly_data.index, forest_norm, label="Forest Loss")
plt.plot(yearly_data.index, agriculture_norm, label="Agricultural Expansion")
plt.plot(yearly_data.index, cattle_norm, label="Cattle Density")
plt.xlabel("Year")
plt.ylabel("Normalized Value (0–1)")
plt.title("Combined Normalized Trend of Forest Loss, Agriculture & Cattle (Line Graph)")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
